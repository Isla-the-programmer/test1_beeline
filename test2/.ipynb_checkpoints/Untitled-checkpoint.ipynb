# %%
import pandas as pd
import numpy as np

arpu_monthly = pd.read_csv('data/arpu_monthly.csv', sep = ',')
change_tariff = pd.read_csv('data/change_tariff.csv', sep = ',')
traffic = pd.read_csv('data/traffic.csv', sep = ',')
dict_tariff = pd.read_csv('data/dict_tariff.csv', sep = ',')
print(arpu_monthly)
print(change_tariff)
print(traffic)
print(dict_tariff)
# Out:
#        ARPU_1M    TIME_KEY  ID_NUMBER
# 0        11.62  2019-08-01       5746
# 1       842.68  2019-06-01       5746
# 2       266.33  2019-07-01       5746
# 3        36.46  2019-09-01       5746
# 4       263.32  2019-05-01       5746
# ...        ...         ...        ...
# 78793  3536.49  2019-06-01      38776
# 78794  2739.08  2019-05-01      38776
# 78795  7925.71  2019-07-01      38776
# 78796  6364.12  2019-09-01      38776
# 78797  3226.92  2019-04-01      38776
#
# [78798 rows x 3 columns]
#                     TIME_KEY  AVG_ARPU_PREV_3M  AVG_ARPU_NEXT_3M  ID_NUMBER  \
# 0      2019-10-01 00:00:00.0            104.80           3466.71       5746
# 1      2019-10-01 00:00:00.0           1942.23           2789.06      11102
# 2      2019-10-01 00:00:00.0           4485.72           5500.61      13477
# 3      2019-10-01 00:00:00.0           1959.71          10069.25      16127
# 4      2019-10-01 00:00:00.0           1337.31            862.58      16626
# ...
